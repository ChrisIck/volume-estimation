# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
sys.path.append('/home/ci411/volume_estimation')
import eval_funcs
import model_funcs
import pandas as pd
import torch
from IPython.display import IFrame
from tqdm import tqdm
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
experiment_name = '081922_batch_size'
plt.style.use('dark_background')

fig_curves = eval_funcs.plot_experiment_curves(experiment_name, offset=50, cmap='Set2',\
                                               max_len=100, verbose=False)
'''
print("Test Metrics")
test_metrics = eval_funcs.plot_experiment_metrics(experiment_name, split='test')

print("Validation Metrics")
val_metrics = eval_funcs.plot_experiment_metrics(experiment_name, split='val')

print("Train Metrics")
train_metrics = eval_funcs.plot_experiment_metrics(experiment_name, split='train')
'''
# Out:
# '\nprint("Test Metrics")\ntest_metrics = eval_funcs.plot_experiment_metrics(experiment_name, split=\'test\')\n\nprint("Validation Metrics")\nval_metrics = eval_funcs.plot_experiment_metrics(experiment_name, split=\'val\')\n\nprint("Train Metrics")\ntrain_metrics = eval_funcs.plot_experiment_metrics(experiment_name, split=\'train\')\n'

# %%
experiment_name = '081922_l2_reg'
plt.style.use('dark_background')

fig_curves = eval_funcs.plot_experiment_curves(experiment_name, offset=50, cmap='Set2',\
                                               max_len=500, verbose=False)
'''
print("Test Metrics")
test_metrics = eval_funcs.plot_experiment_metrics(experiment_name, split='test')

print("Validation Metrics")
val_metrics = eval_funcs.plot_experiment_metrics(experiment_name, split='val')

print("Train Metrics")
train_metrics = eval_funcs.plot_experiment_metrics(experiment_name, split='train')
'''
# Out:
# '\nprint("Test Metrics")\ntest_metrics = eval_funcs.plot_experiment_metrics(experiment_name, split=\'test\')\n\nprint("Validation Metrics")\nval_metrics = eval_funcs.plot_experiment_metrics(experiment_name, split=\'val\')\n\nprint("Train Metrics")\ntrain_metrics = eval_funcs.plot_experiment_metrics(experiment_name, split=\'train\')\n'

# %%
experiment_name = '081922_learning_rate'
plt.style.use('dark_background')

fig_curves = eval_funcs.plot_experiment_curves(experiment_name, offset=50, cmap='Set2',\
                                               max_len=300, verbose=False)
'''
print("Test Metrics")
test_metrics = eval_funcs.plot_experiment_metrics(experiment_name, split='test')

print("Validation Metrics")
val_metrics = eval_funcs.plot_experiment_metrics(experiment_name, split='val')

print("Train Metrics")
train_metrics = eval_funcs.plot_experiment_metrics(experiment_name, split='train')
'''
# Out:
# '\nprint("Test Metrics")\ntest_metrics = eval_funcs.plot_experiment_metrics(experiment_name, split=\'test\')\n\nprint("Validation Metrics")\nval_metrics = eval_funcs.plot_experiment_metrics(experiment_name, split=\'val\')\n\nprint("Train Metrics")\ntrain_metrics = eval_funcs.plot_experiment_metrics(experiment_name, split=\'train\')\n'

# %%
experiment_name = '081922_sched_thres'
plt.style.use('dark_background')

fig_curves = eval_funcs.plot_experiment_curves(experiment_name, offset=50, cmap='Set2',\
                                               max_len=100, verbose=False)
'''
print("Test Metrics")
test_metrics = eval_funcs.plot_experiment_metrics(experiment_name, split='test')

print("Validation Metrics")
val_metrics = eval_funcs.plot_experiment_metrics(experiment_name, split='val')

print("Train Metrics")
train_metrics = eval_funcs.plot_experiment_metrics(experiment_name, split='train')
'''
# Out:
# '\nprint("Test Metrics")\ntest_metrics = eval_funcs.plot_experiment_metrics(experiment_name, split=\'test\')\n\nprint("Validation Metrics")\nval_metrics = eval_funcs.plot_experiment_metrics(experiment_name, split=\'val\')\n\nprint("Train Metrics")\ntrain_metrics = eval_funcs.plot_experiment_metrics(experiment_name, split=\'train\')\n'
