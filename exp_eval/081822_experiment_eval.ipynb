# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
sys.path.append('/home/ci411/volume_estimation')
import eval_funcs
import model_funcs
import pandas as pd
import torch
from IPython.display import IFrame
from tqdm import tqdm
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# Using device: cpu
#
# Using device: cpu

# %%
experiment_name = '081822_comp'
plt.style.use('dark_background')

fig_curves = eval_funcs.plot_experiment_curves(experiment_name, offset=10, cmap='Set2', verbose=True)

test_metrics = eval_funcs.plot_experiment_metrics(experiment_name, split='test')
val_metrics = eval_funcs.plot_experiment_metrics(experiment_name, split='val')
train_metrics = eval_funcs.plot_experiment_metrics(experiment_name, split='train')
# Out:
# Model prop0_20k_081822 has completed 1000 epochs
# Model prop1_20k_081822 has completed 1000 epochs
# Model prop2_20k_081822 has completed 1000 epochs
# Model prop3_20k_081822 has completed 1000 epochs
# Model prop4_20k_081822 has completed 1000 epochs
# Model prop5_20k_081822 has completed 1000 epochs
# Model prop6_20k_081822 has completed 1000 epochs

# %%
experiment_name = '081922_rt60_comp'
model_list = ['prop{}_rt60_081922'.format(i) for i in [0,1,2,3,4,5,6]]
print(model_list)
eval_funcs.evaluate_experiment(experiment_name, model_list=model_list, log=True, same_features=False, gen_plots=False, target='rt60')
# Out:
# ['prop0_rt60_081922', 'prop1_rt60_081922', 'prop2_rt60_081922', 'prop3_rt60_081922', 'prop4_rt60_081922', 'prop5_rt60_081922', 'prop6_rt60_081922']
# Loading prop0_rt60_081922
# Loading features from /scratch/ci411/sonos_rirs/features/081522_20k/081822_20k_prop0/feature_df.csv
# labels
# Computing metrics on prop0_rt60_081922
# Loading test dataloader...
# Saving metrics to /scratch/ci411/sonos_rirs/models/081922_rt60_comp/prop0_rt60_081922/test_metrics.json
# Loading val dataloader...
# Saving metrics to /scratch/ci411/sonos_rirs/models/081922_rt60_comp/prop0_rt60_081922/test_metrics.json
# Loading train dataloader...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <cell line: 4>()
#       2 model_list = ['prop{}_rt60_081922'.format(i) for i in [0,1,2,3,4,5,6]]
#       3 print(model_list)
# ----> 4 eval_funcs.evaluate_experiment(experiment_name, model_list=model_list, log=True, same_features=False, gen_plots=False, target='rt60')
#
# File ~/volume_estimation/eval_funcs.py:348, in evaluate_experiment(experiment_name, model_list, log, same_features, gen_plots, target)
#     346 print("Loading train dataloader...")
#     347 train_dataloader = model_funcs.create_dataloader(feature_df[feature_df['split']=='train'], log=log, target=target)
# --> 348 train_metrics = compute_eval_metrics(train_dataloader, model, log=log)
#     349 train_path = os.path.join(MODELS_DIR, experiment_name, model_name, 'train_metrics.json')
#     350 print('Saving metrics to {}'.format(train_path))
#
# File ~/volume_estimation/eval_funcs.py:247, in compute_eval_metrics(dataloader, model, log, verbose)
#     245 (x, y) = (x.to(device), y.to(device))
#     246 y = y.item()
# --> 247 pred = model(x).item()
#     248 target_sum += np.sum(y)
#     249 pred_sum += np.sum(pred)
#
# File /scratch/ci411/.conda/envs/s3d_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/volume_estimation/model_funcs.py:240, in Baseline_Model.forward(self, x)
#     238 def forward(self, x):
#     239     for layer in self.net:
# --> 240         x = layer(x)
#     241     return x
#
# File /scratch/ci411/.conda/envs/s3d_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /scratch/ci411/.conda/envs/s3d_env/lib/python3.8/site-packages/torch/nn/modules/conv.py:457, in Conv2d.forward(self, input)
#     456 def forward(self, input: Tensor) -> Tensor:
# --> 457     return self._conv_forward(input, self.weight, self.bias)
#
# File /scratch/ci411/.conda/envs/s3d_env/lib/python3.8/site-packages/torch/nn/modules/conv.py:453, in Conv2d._conv_forward(self, input, weight, bias)
#     449 if self.padding_mode != 'zeros':
#     450     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     451                     weight, bias, self.stride,
#     452                     _pair(0), self.dilation, self.groups)
# --> 453 return F.conv2d(input, weight, bias, self.stride,
#     454                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:
